# %%
import pandas as pd
import numpy as np
from pdfminer.high_level import *
from pdfminer.layout import *
from io import StringIO
import re

# %%
with open('org_charts/qsi_text.tx', 'w') as out_file:
    with open('org_charts/Queens- Staten Island Property Org Chart - July  2020.pdf', 'rb') as fin:
        extract_text_to_fp(fin, out_file, laparams=LAParams(all_texts=True), output_type='text', codec=None, )

# %%
qsi_text = extract_text('org_charts/Queens- Staten Island Property Org Chart - July  2020.pdf')
brooklyn_text = extract_text('org_charts/Brooklyn Property Organizational Chart - July 2020.pdf')
manhattan_text = extract_text('org_charts/Manhattan Property Organizational Chart - July  2020.pdf')
bronx_text = extract_text('org_charts/Bronx Property Organizational Chart  - July  2020.pdf')
ngo_text = extract_text('org_charts/NGO1 Property Organizational Chart July  2020.pdf')
mf_text = extract_text('org_charts/Mixed Finance Property Org Chart - July 2020.pdf')

print(brooklyn_text)
# Out:
#
#
# BROOKLYN PROPERTY MANAGEMENT DEPARTMENT
# JULY 2020 ORGANIZATIONAL CHART
#
#
#
# Office Manager
# Angela Rollins
# (718) 491-6804
#
# Regional Asset Manager
# Gerard Middleton
# (917) 842-2407
#
#
# Albany - (718) 774-8100
# PM – Sharon Scott / PMS – Lindsay
# Wade
#
# Breukelen - (718) 649-7630
# PM – Patricia Williams-Brewster,
# /PMS – Michael Johnson
#
#
# Cypress Hills - (718) 647-1820
# PM – Lula Richards /PMS Tara Lucas
#
# Ocean Hill - (718) 443-2991
# PM – Toshia Smith / PMS – Elijah
# Hardge
#
#
#
# Pink - (718) 647-4800
# PM-Stephen Barclay / PMS -
# Veronica Hollman
#
# Reid - (718) 467-2212
# PM – Stephanie Alonso / PMS –
# Tiffany Deputy
#
#
#
# Assistant to the Director
#
# Joan Akers
# 718-491-6866
#
# Regional Asset Manager
# Michael Iezza
# 917-583-3503
#
# Carey/Haber/CI IB - (718) 372-
# 4100
# PM - Ronald Cholewa / PMS –
# David Rios
# Glenwood - (718) 251-5583
# PM – Michael Robertson/ PMS –
# Mariam Thorne
#
# Marcus Garvey - (718) 345-9707
# PM – Valerie Atkins / PMS – Alexis
# Nieves
#
# O’Dwyer/Gravesend/CI 8 - (718)
# 449-1800
# PM – Vacant / PMS – Edward
# Jackson
#
# Penn-Wortman - (718) 257-2717
# PM –Jia Feng Wu/ PMS- Lois Kelly
#
#
# Surfside/Coney Island/Coney 4&5
# - (718) 449-2936
# PM – Kazi Rahen / PMS – Lori
# Castellano
#
# Red Hook East - (718) 752-2307
# PM - Moniece McCray / PMS-
# Michael Wilkins -
#
#
#
#
#
#
#
#
#
#
#
# Joseph Courtien, VP of Operations
# O: 212-306-3401 C: 646-208-4824
#
# Angela Gadson-Floyd, Director
# Brooklyn Borough Office
# 816 Ashford Street, NY, NY 11207
#  (646)-831-8364
#
# Regional Asset Manager
# Alicia Maynard
#  (646) 946-5887
#
# Regional Asset Manager
# Alverista Hall
#   (646) 265-0492
#
#
# Borinquen Plaza - (718) 782-7803
# PM – Margie Taylor   PMS – Carlos
# Gonzalez
#
# Cooper Park - (718) 389-9230
# PM – Shakia Smith / PMS – Fia Cook
#
#
# Park Rock - (646) 994-4355
# PM – Vacant / PMS Cleveland Dunn
#
# Sumner - (718) 453-4343
# PM – Michael Jones / PMS – Donetta
# Johnson-Geliga
#
# Roosevelt - (646) 994-4355
# PM – Gail Bordeaux / PMS- David
# Graham
#
#
#
# Williamsburg - (718) 387-0908
# PM - Lyonnel Changeau / PMS –
# Elizabeth Diaz
#
#
#
#
#
#
#
#
# Brevoort - (718) 493-1600
#
# PM – Khrishaun Williams /PMS - John
#
# Brown
#
# Gowanus (718) 522-5405
# PM - Tena Morgan /PMS- Bryan Mieles
#
#
#
# Kingsborough - (718) 774-6615
# PM – Ayodeji Festus/ PMS - Cassandra
# Newkirk
#
# Lafayette - (718) 857-9790
# PM – Angela Yancy-Foster/ PMS - Robin
# Waring
#
# Sheepshead/Nostrand - (718) 332-1813
# PM - Tobi Brown/ PMS – Alex Geliga
#
# Red Hook West - (718) 752-2353
# PM- Verhonda Johnson / PMS – Nymiah
# Branch
#
# Wyckoff - (718) 855-9363
# PM - Shelisa Reid / PMS - Beana Alston
#
#
# Regional Asset Manager
# Renee Taylor
# (929) 448-8307
#
#
# Farragut - (718) 752-2331
# PM – Angela Williams / / PMS – Glenn Rueda
#
#
#
#
#
#
# Ingersoll - (718) 624-7316
# PM – Michael Wyands / PMS Elizabeth Tapia
#
#
# Marcy - (718) 875-7705
# PM – Tedric Gamble / PMS-Tyrone Grant
#
# Stuyvesant - (718) 453-4900
# PM – Michael Lawrence / PMS – Tuesdai
# Gaskin
#
# Tompkins - (718) 782-2920
# PM – Tyrone Washington/ PMS – Wallace
# Butler -
#
# Whitman - (718) 875-6690
# PM – Cyriaca Decaille / PMS - Douglas Stokes
#
#
# Planning & Scheduling Unit PMS
# Jose Ortega
# Brenda Perez
# Omar Glover
# Sharon Brown
# Vacant
#
# Deputy Director
# Kelvin Darby
# 646-531-1382
#
#
# Administrator
# John Frassetti,
# 718-561-9593
#
# Bricklayer Supv (2)
# Bricklayer (14)
# Elec Supv (1)
# Elec (8)
# Elec Hlpr (4)
# Paint Supv (5)
# Painter (36)
# Plastr Supv (5)
# Plastr Supv (boro) (1)
# Plastr (55)
# Mason Helper (6)
# Caretaker P (52)
# Roofer Supv (1)
# Roofer (4)
# Painter Apprentice (37)
#
# Administrator
# Edward Burch
# 646-770-5910
# Carpenter Supv (2)
# Carpenter (46)
# Exter Supv (2)
# Exter (20)
# Plumber Supv (2)
# Plumber (13)
# Plumber Hlpr (12)
# Glazier Supv (1)
# Glazier (5)
#
#
# Revised 6/30/20

# %%
qsi_dev_names = re.compile(r'(\n{1})([\w\s\/\']*)(?=PM\s)')

qsi_pm_pms = re.compile(r'(\n{1}PM[A-Za-z\s\/–-]*)') 

qsi_ram = re.compile(r'(Regional Asset Manager[\sA-Za-z]*)(?=\s*[\d\(\)-]*)')
