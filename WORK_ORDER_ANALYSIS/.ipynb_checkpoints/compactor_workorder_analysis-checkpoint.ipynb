# %% [markdown]
# ## WMP Maximo compactor analysis

# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
import matplotlib.cm as cm
import matplotlib as mpl
from matplotlib.gridspec import GridSpec
import matplotlib.pyplot as plt
import seaborn as sns
from textwrap import wrap

# %%
#set to display full column
pd.set_option('display.max_columns', None)

# %% [markdown]
# DATA CLEANING/CATEGORIZATION PROCESS (DEPRECATED)
#
# 1. Check data type for each column and make necessary conversions (i.e. datetime)
# 2. Split LOCATION string based on period into new columns
# 3. Move GND01 entries to ROOM column
# 4. Concatenate problem and failure columns
# 5. Export unique problem+failure entries
# 6. Manually classify problemandfailure codes based on observation and count of entries into:
#     1. BULK
#     2. INTCOMPACTOR
#     3. EXTCOMPACTOR
#     4. PESTS
#     5. PAINT
#     6. PLUMBING
#     7. DOOR
#     8. ELEC
#     9. LIGHT
#     10. OTHER
# 7. Add categorizations back into main dataframe
# 8. Export miscategorized compactor entries for manual reclassification (403 interior compactor entries located in 'GROUNDS')
# 9. Join (overwrite using .update) manually corrected miscategorized compactor entries
# 10. Write cleaned csv file for analysis

# %%
# #load csv
# comp_data_raw = pd.read_csv("comp_raw.csv")c

# %%
##1A. Checking data types before processing to avoid errors
# print(comp_data_raw.dtypes)

# %%
# #1B. Convert date columns to datetime
# comp_data_raw["REPORTDATE"] = pd.to_datetime(comp_data_raw["REPORTDATE"])
# comp_data_raw["ZZCREATEDATE"] = pd.to_datetime(comp_data_raw["ZZCREATEDATE"])
# comp_data_raw["SCHEDSTART"] = pd.to_datetime(comp_data_raw["SCHEDSTART"],errors='coerce')
# comp_data_raw["TARGSTARTDATE"] = pd.to_datetime(comp_data_raw["TARGSTARTDATE"], errors='coerce')
# comp_data_raw["ACTSTART"] = pd.to_datetime(comp_data_raw["ACTSTART"])
# comp_data_raw["ACTFINISH"] = pd.to_datetime(comp_data_raw["ACTFINISH"])
# comp_data_raw["STATUSDATE"] = pd.to_datetime(comp_data_raw["STATUSDATE"])

# %%
##1C. Save data types to variable to check later if you're bugging out
##Deprecated
# data_types = comp_data_raw.dtypes

# %%
# ## 2. Split "LOCATION"
# # KEY: 0 - TDS, 1 - BUILDING, 2 - STAIRHALL, 3 - ROOM
# # new data frame with split value columns 
# split_loc = comp_data_raw["LOCATION"].str.split(".", expand = True) 
# # assign new columns based on split
# comp_data_raw["TDS"]= split_loc[0] 
# comp_data_raw["BUILDING"]= split_loc[1]
# comp_data_raw["STAIRHALL"]= split_loc[2] 
# comp_data_raw["ROOM"]= split_loc[3]

# %%
# #3A. Copy GND01 and erase GND01 from BUILDING column
# comp_data_raw["ROOM"] = np.where(comp_data_raw.BUILDING.str.contains("GND01")== True, "GND01", comp_data_raw["ROOM"])
# comp_data_raw["BUILDING"] = np.where(comp_data_raw.BUILDING.str.contains('GND01') == True, "", comp_data_raw["BUILDING"])

# %%
# #3B. Copy GND01 to ROOM column and erase GND01 from STAIRHALL column
# comp_data_raw["ROOM"] = np.where(comp_data_raw.STAIRHALL.str.contains("GND01")== True, "GND01", comp_data_raw["ROOM"])
# comp_data_raw["STAIRHALL"] = np.where(comp_data_raw.STAIRHALL.str.contains('GND01') == True, "", comp_data_raw["STAIRHALL"])

# %%
# #DEPRECATED because conversion to GND01 would leave the location unclear without building number
# #Put Parking lot encodings in ROOM
# comp["ROOM"] = np.where(comp.BUILDING.str.contains('PK01', regex = False) == True, 'PK01', comp["ROOM"])
# #Delete parking lot encodings from BUILDING
# comp_data_raw["BUILDING"] = np.where(comp_data_raw.BUILDING.str.contains('PK01', regex = False) == True, '', comp_data_raw['BUILDING'])

# %%
# #4. Concatenate problem and failure code
# comp_data_raw['PROBLEMANDFAILURE'] = comp_data_raw['PROBLEMCODE'] + comp_data_raw['FAILURECODE']

# %%
##5A. Create new df to output problem and failure codes
##DEPRECATED
#new_df = comp_data_raw.PROBLEMANDFAILURE.value_counts().rename_axis("unique_values").reset_index(name="counts")

# %%
##5B. Export to csv 
##DEPRECATED
#new_df.to_csv(r'datadict.csv', index = False)

# %%
## 6. Explanation of manual classification [NOT COMPLETED]:
## 1. BULK -- 
## 2. INTCOMPACTOR -- 
## 3. EXTCOMPACTOR --
## 4. PESTS --
## 5. PAINT --
## 6. PLUMBING --
## 7. DOOR --
## 8. ELEC --
## 9. LIGHT --
## 10. OTHER --

# %%
# # 7A. Import manual work order categorizations
# work_ord_cat = pd.read_csv("workorder_data_dictionary.csv")

# %%
# # 7B. Create blank dictionary w/ keys
# cat_dict = {"BULK":[],"INTCOMPACTOR":[],"EXTCOMPACTOR":[],"PESTS":[],"PAINT":[], "PLUMBING":[],"DOOR":[],"ELEC":[],"LIGHT":[],"OTHER":[]}

# %%
# # 7C. Iterate over rows and add unique codes to dictionary based on key value
# for i in range(len(work_ord_cat)): 
#     cat_dict[work_ord_cat.loc[i, "CATEGORY"]].append(work_ord_cat.loc[i, "PROBLEMCODE_FAILURECODE_unique"])

# %%
# # 7D. Create blank category column in raw data df
# comp_data_raw["CATEGORY"] = ""

# %%
# # 7E. Test for equivalency PROBLEMANDFAILURE column == category dictionary and add categorization to empty "CATEGORY" column
# for key, value in cat_dict.items():
#     for item in value:
#         comp_data_raw["CATEGORY"] = np.where(comp_data_raw.PROBLEMANDFAILURE.str.contains(item, regex = False) == True, key, comp_data_raw["CATEGORY"])

# %%
## 7F. Testing For Success of categorization process TM
## DEPRECATED
#np.where(comp_data_raw["CATEGORY"] == '')

# %%
# ## 7G. Fix mistakes :/
# #print(comp_data_raw.loc[15546,'PROBLEMANDFAILURE'])
# #print(comp_data_raw.loc[23014,'PROBLEMANDFAILURE'])
# comp_data_raw.loc[15546,'CATEGORY'] = 'PAINT'
# comp_data_raw.loc[23014,'CATEGORY'] = 'OTHER'

# %%
## 8A. Export interior compactors where CATEGORY == INTCOMPACTOR & ROOM == GND01
##DEPRECATED
#miscat_comp = comp_data_raw[(comp_data_raw.CATEGORY == "INTCOMPACTOR") & (comp_data_raw.ROOM == "GND01")]
#miscat_comp.to_csv(r'miscat_comp.csv', index = False)

# %%
#8B. Manually correct 403 miscategorized entries. File is saved as miscat_comp.csv. Explanation of process:
#1. If basement, room, or interior compactor is entered anywhere, leave as INTCOMPACTOR and change "ROOM" column to "Unknown - Originally entered as 'GND01'"
#2. Else, change "CATEGORY" to 'EXTCOMPACTOR'
#3. Cross-check with Dev Data_ Use this one.xlsx spreadsheet to ensure exterior compactors exist at development
#4. If 'NOISYCOMPACTOR' is in the problem or failurecode, examine other columns to ensure it is actually an external compactor

# %%
# #9A. Join re-categorized data to comp_data_raw
# recat_comp = pd.read_csv("miscat_comp.csv")
# comp_data_raw.update(recat_comp)

# %%
# #9B. Reset date columns to datetime
# comp_data_raw["REPORTDATE"] = pd.to_datetime(comp_data_raw["REPORTDATE"])
# comp_data_raw["ZZCREATEDATE"] = pd.to_datetime(comp_data_raw["ZZCREATEDATE"])
# comp_data_raw["SCHEDSTART"] = pd.to_datetime(comp_data_raw["SCHEDSTART"],errors='coerce')
# comp_data_raw["TARGSTARTDATE"] = pd.to_datetime(comp_data_raw["TARGSTARTDATE"], errors='coerce')
# comp_data_raw["ACTSTART"] = pd.to_datetime(comp_data_raw["ACTSTART"])
# comp_data_raw["ACTFINISH"] = pd.to_datetime(comp_data_raw["ACTFINISH"])
# comp_data_raw["STATUSDATE"] = pd.to_datetime(comp_data_raw["STATUSDATE"])

# %%
# #10. Write cleaned file
# comp_data_raw.to_csv(r'comp_clnd.csv',index = False)

# %% [markdown]
# MAXIMO COMPACTOR CATEGORY SUMMARY STATISTICS PROCESS

# %% [markdown]
# Setup
# 1. Import 'comp_clnd.csv', set datetime, save datatypes
# 2. Set Seaborn plot settings
#
# Consolidation Summary Stats Process
# 1. Groupby consolidation
# 2. Pivot on category
# 3. For loop through df and export bar charts of category counts
#
# Development Summary Stats Process
# 1. Create list of unique consolidations tds numbers
# 2. For loop through unique list returning dataframes == unique value
#     3. For loop through each row for each development
#         4. Drop columns with just one or less category
#
# Room Location Summary Stats Process
# 1.

# %%
#1A. Import comp_clnd.csv
comp = pd.read_csv("comp_clnd.csv")

#1B. Change to datetime and change TDS nums to int32
comp["REPORTDATE"] = pd.to_datetime(comp["REPORTDATE"])
comp["ZZCREATEDATE"] = pd.to_datetime(comp["ZZCREATEDATE"])
comp["SCHEDSTART"] = pd.to_datetime(comp["SCHEDSTART"],errors='coerce')
comp["TARGSTARTDATE"] = pd.to_datetime(comp["TARGSTARTDATE"], errors='coerce')
comp["ACTSTART"] = pd.to_datetime(comp["ACTSTART"])
comp["ACTFINISH"] = pd.to_datetime(comp["ACTFINISH"])
comp["STATUSDATE"] = pd.to_datetime(comp["STATUSDATE"])
comp.CONSOLIDATED_TDS_NUM = comp.CONSOLIDATED_TDS_NUM.astype('int32')
comp.TDS_NUM = comp.TDS_NUM.astype('int32')
comp.TDS = comp.TDS.astype('int32')
comp.BUILDING = pd.to_numeric(comp['BUILDING'], errors='coerce')
#1C. Save data types to variable to check later if you're bugging out
data_types = comp.dtypes
# Out:
# C:\Users\Justin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (46) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# #2. Setup for plotting - set style and create custom color palette

#set style
sns.set(style="whitegrid")

#custom color pallette (connected commmunities color palette)
con_colors = ['#587EBF', '#548F8F', '#FD765B', '#C86FB4','#8FC7A1', '#AEE9FA']
#setting palette
sns.set_palette(sns.color_palette(con_colors))

# %% [markdown]
# Prep for Category Bar Charts

# %%
# #1. Group comp_clnd by consolidation, tds, num for both tds and consolidations 
# #   to get the sums of each kind of category for each TDS
# tds_cat_grp = comp.groupby(['CONSOLIDATED_TDS_NUM', 'CONSOLIDATED_NAME','TDS_NUM','DEVELOPMENT_NAME','CATEGORY']).size().reset_index(name='Freq')

# %%
# #2. Pivot tds_cat_grp to create columns for each type of compactor category
# tds_cats_cnt = tds_cat_grp.pivot_table(index=['CONSOLIDATED_TDS_NUM', 'CONSOLIDATED_NAME','TDS_NUM','DEVELOPMENT_NAME'], columns='CATEGORY', values='Freq').reset_index().rename_axis(None, axis=1)
# #fill na with 0 for graphs
# tds_cats_cnt = tds_cats_cnt.fillna(0)
# #change all floats to int
# tds_cats_cnt[tds_cats_cnt.columns[4:14]] = tds_cats_cnt[tds_cats_cnt.columns[4:14]].astype(int)
# #Reset column order
# tds_cats_cnt = tds_cats_cnt[["CONSOLIDATED_NAME", "CONSOLIDATED_TDS_NUM", "DEVELOPMENT_NAME", "TDS_NUM", "INTCOMPACTOR","EXTCOMPACTOR", "PESTS", "PLUMBING", "PAINT", "BULK", "DOOR", "ELEC", "LIGHT","OTHER"]]
# #Rename columns for legibility
# tds_cats_cnt = tds_cats_cnt.rename(columns={'INTCOMPACTOR': 'Interior Compactor', 'EXTCOMPACTOR': 'Exterior Compactor', 'PESTS': 'Pests', 'PLUMBING':'Plumbing','ELEC': 'Electricity', 'LIGHT':'Lights', 'PAINT':'Painting', 'DOOR':'Door', 'BULK':'Bulk', 'OTHER': 'Other'})
# #taking categories and turning into a list for graphs
# cat_lst = list(tds_cats_cnt.columns[4:14])

# %% [markdown]
# Consolidation Summary Stats

# %%
# #1. Groupby consolidation and sum category columns
# consol_cats_cnt = tds_cats_cnt.groupby(['CONSOLIDATED_TDS_NUM', 'CONSOLIDATED_NAME']).sum().reset_index().drop(columns=["TDS_NUM"])

# %%
# #2. Loop through every row and create a graph based on consolidation information
# for ind in range(len(cons_cat)):
#     #zip data to axes
#     ax = sns.barplot(x=cat_lst,y=consol_cats_cnt.iloc[ind,2:12])
#     #set axis titles
#     ax.set(xlabel="Work Type", ylabel = "# of Work Orders")
#     #set tick label rotation to display full label
#     ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#     #set titles
#     ax.set_title('\n'.join(wrap(consol_cats_cnt.iloc[ind,1]+" Consolidation Work Orders in Compactor Locations 1/1/2019-7/1/2020")))
#     #honestly not sure this is changing anything but hell, a tighter graph would be great
#     plt.tight_layout()
#     #saving as svg
#     plt.savefig('Consolidation_BarCharts/svg/'+str(consol_cats_cnt.iloc[ind,0])+'_'+consol_cats_cnt.iloc[ind,1]+'_WorkOrder_Category_BarChart.svg')
#     #saving as png
#     plt.savefig('Consolidation_BarCharts/png/'+str(consol_cats_cnt.iloc[ind,0])+'_'+consol_cats_cnt.iloc[ind,1]+'_WorkOrder_Category_BarChart.png', dpi=300)
#     #closing axes, and figure etc
#     plt.cla()
#     plt.clf()

# %% [markdown]
# Development Summary Stats

# %%
# #1. Iterate through and export graphs
# #iterating through unique consolidation numbers
# for consol_num in tds_cats_cnt.CONSOLIDATED_TDS_NUM.unique().tolist():
#     #testing if the consolidation only has one development in it
#     if len(tds_cats_cnt.loc[tds_cats_cnt['CONSOLIDATED_TDS_NUM'] == consol_num]) == 1:
#         pass
#     else:
#         #creating df of the consolidation
#         consol_df = tds_cats_cnt.loc[tds_cats_cnt['CONSOLIDATED_TDS_NUM'] == consol_num].reset_index(drop=True)
#         #iterating through every row
#         for ind in range(len(consol_df)):
#             #print(str(consol_df.iloc[ind,2]))
#             #create dataframe from row
#             tds_df = pd.DataFrame(consol_df.loc[ind]).transpose()
#             #jettison zero values from row
#             tds_df = tds_df.loc[:, (tds_df !=0).any(axis=0)]
#             #test if len of dataframe is only one category
#             if len(tds_df.iloc[0,4:]) <= 1:
#                 pass
#             else:
#             #create list of categories to zip
#                 cats = tds_df.iloc[0,4:].index.tolist()
#             #zip data to axes
#                 ax = sns.barplot(x=cats,y=tds_df.iloc[0,4:])
#             #set axis titles
#                 ax.set(xlabel="Work Type", ylabel = "# of Work Orders")
#             #set tick label rotation to display full label
#                 ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#             #set titles
#                 ax.set_title('\n'.join(wrap(consol_df.iloc[ind,2].title()+" Development Work Orders in Compactor Locations 1/1/2019-7/1/2020")))
#             #honestly not sure this is changing anything but hell, a tighter graph would be great
#                 plt.tight_layout()
#             #saving as svg
#                 plt.savefig('Development_BarCharts/svg/'+str(consol_df.iloc[ind,3])+'_'+str(consol_df.iloc[ind,2])+'_WorkOrder_Category_BarChart.svg')
#             #saving as png
#                 plt.savefig('Development_BarCharts/png/'+str(consol_df.iloc[ind,3])+'_'+str(consol_df.iloc[ind,2])+'_WorkOrder_Category_BarChart.png', dpi=300)
#             #closing axes, and figure etc
#                 plt.cla()
#                 plt.clf()

# %% [markdown]
# Room Location (and maybe create date?) Summary Stats
#
# Idea: multiple line chart showing category of work order over time for each development? consolidation? room? not enough data for room level analysis
#
# GND room values don't always have an associated building code
#
# Does "Grounds" mean anything to staff w/o associated building code?

# %%
comp[comp.ROOM.isna() & (comp.CATEGORY == "EXTCOMPACTOR")]
# Out:
#       GEOGRAPHICAL_BOROUGH_NAME  NEW_BOROUGH_GROUPING       RAM  \
# 502                       Bronx          Private Mgmt  WILLIAMS
# 834                   Manhattan             Manhattan    GADSON
# 1128                  Manhattan         Mixed Finance    DINGLE
# 1156                     Queens  Queens-Staten Island      DREW
# 1311                  Manhattan                  NGO1    TURNER
# ...                         ...                   ...       ...
# 22857                     Bronx         Mixed Finance    DINGLE
# 22869                     Bronx                  NGO1  MCMILLAN
# 22986                     Bronx                 Bronx    BETHEA
# 22999                     Bronx                 Bronx  THEODORE
# 23070                  Brooklyn         Mixed Finance    DINGLE
#
#                            CONSOLIDATED_NAME  CONSOLIDATED_TDS_NUM  \
# 502    Building Management Associates (BX 1)                   530
# 834                              King Towers                    30
# 1128                               Amsterdam                    22
# 1156                                 Redfern                    55
# 1311                              East River                     9
# ...                                      ...                   ...
# 22857                      Saint Mary's Park                    93
# 22869                             Mott Haven                   121
# 22986                    Eastchester Gardens                    34
# 22999                                  Adams                   118
# 23070                               Bushwick                    86
#
#                    DEVELOPMENT_NAME  TDS_NUM             ADDRESS_LINE_1  \
# 502    HOE AVENUE-EAST 173RD STREET      215            1700 HOE AVENUE
# 834                     KING TOWERS       30       70 WEST 115TH STREET
# 1128             HARBORVIEW TERRACE      262       520 WEST 56TH STREET
# 1156                        REDFERN       55  14-78 BEACH CHANNEL DRIVE
# 1311                     EAST RIVER        9   425GAR EAST 102ND STREET
# ...                             ...      ...                        ...
# 22857             SAINT MARY'S PARK       93       550 CAULDWELL AVENUE
# 22869                    MOTT HAVEN      121      355 EAST 143RD STREET
# 22986           EASTCHESTER GARDENS       34          3055 BOUCK AVENUE
# 22999                         ADAMS      118          710 TINTON AVENUE
# 23070                      BUSHWICK       86        811 FLUSHING AVENUE
#
#       BUILDING_NUM LOCATION LOCATION_TYPE OWNERGROUP SOURCESYSID  \
# 502             01   215.01      BUILDING     DEV530      MAXIMO
# 834            NaN      030   DEVELOPMENT   TSDWASTE      MAXIMO
# 1128            01   262.01      BUILDING   TSDWASTE      MAXIMO
# 1156            04   055.04      BUILDING     QSELEC      MAXIMO
# 1311            11   009.11      BUILDING   TSDWASTE      MAXIMO
# ...            ...      ...           ...        ...         ...
# 22857           01   093.01      BUILDING   TSDWASTE      MOBILE
# 22869           07   121.07      BUILDING   TSDWASTE      MAXIMO
# 22986           06   034.06      BUILDING   TSDWASTE      MAXIMO
# 22999           05   118.05      BUILDING     BXELEC      MAXIMO
# 23070          NaN      086   DEVELOPMENT   TSDWASTE      MAXIMO
#
#       CALL_CENTER_TYPE      PARENT       WONUM      TRADE_TYPE  \
# 502            Non-CCC  66450503.0  66450503.0     MAINTENANCE
# 834            Non-CCC  72650965.0  72650965.0     MAINTENANCE
# 1128           Non-CCC  65791005.0  65791005.0     MAINTENANCE
# 1156           Non-CCC  65456517.0  65456517.0  SKILLED TRADES
# 1311           Non-CCC  65910402.0  65910402.0     MAINTENANCE
# ...                ...         ...         ...             ...
# 22857          Non-CCC  68460399.0  68460399.0     MAINTENANCE
# 22869          Non-CCC  72209996.0  72209996.0     MAINTENANCE
# 22986          Non-CCC  73208690.0  73208690.0     MAINTENANCE
# 22999          Non-CCC  74261237.0  74261237.0  SKILLED TRADES
# 23070          Non-CCC  64993851.0  64993851.0     MAINTENANCE
#
#       CRAFT_DESCRIPTION        FAILURECODE            PROBLEMCODE  WOPRIORITY  \
# 502         Maintenance  EXTERIORCOMPACTOR             RETWALLDML         3.0
# 834         Maintenance  EXTERIORCOMPACTOR             RAMDAMAGED         3.0
# 1128        Maintenance  EXTERIORCOMPACTOR            HOSEOILLEAK         3.0
# 1156        Electrician  EXTERIORCOMPACTOR           EXPOSEDWIRES         3.0
# 1311        Maintenance  EXTERIORCOMPACTOR            HOSEOILLEAK         3.0
# ...                 ...                ...                    ...         ...
# 22857       Maintenance  EXTERIORCOMPACTOR        EXTCOMPACTOROOO         3.0
# 22869       Maintenance  EXTERIORCOMPACTOR  LOADERBUCKETNOTMOVING         3.0
# 22986       Maintenance  EXTERIORCOMPACTOR  LOADERBUCKETNOTMOVING         3.0
# 22999       Electrician  EXTERIORCOMPACTOR                NOPOWER         3.0
# 23070       Maintenance  EXTERIORCOMPACTOR         FITTINGOILLEAK         3.0
#
#       REPORTDATE ZZCREATEDATE SCHEDSTART TARGSTARTDATE   ACTSTART  ACTFINISH  \
# 502   2019-04-15   2019-04-14        NaT           NaT 2019-04-14 2019-04-14
# 834   2020-02-24   2020-02-24        NaT           NaT 2020-03-02 2020-03-02
# 1128  2019-03-05   2019-03-05        NaT           NaT 2019-03-07 2019-03-07
# 1156  2019-02-06   2019-02-06        NaT           NaT 2019-02-06 2019-02-06
# 1311  2019-03-17   2019-03-17        NaT           NaT 2019-03-19 2019-03-19
# ...          ...          ...        ...           ...        ...        ...
# 22857 2019-08-25   2019-08-25        NaT           NaT 2019-09-03 2019-09-03
# 22869 2020-01-24   2020-01-24        NaT           NaT 2020-01-29 2020-01-29
# 22986 2020-03-30   2020-03-30        NaT           NaT 2020-03-31 2020-03-31
# 22999 2020-06-29   2020-06-29        NaT           NaT 2020-06-29 2020-06-29
# 23070 2019-01-03   2019-01-03        NaT           NaT 2019-01-09 2019-01-09
#
#       STATUS STATUSDATE DISPOSITION_DESC DISPOSITION_SUB_DESC WORK_DONE_DESC  \
# 502    CLOSE 2019-04-15           CLOSED               Closed      Work Done
# 834    CLOSE 2020-03-03           CLOSED           Inspection      Work Done
# 1128   CLOSE 2019-03-07           CLOSED               Closed      Work Done
# 1156   CLOSE 2019-02-06           CLOSED               Closed      Work Done
# 1311   CLOSE 2019-03-20           CLOSED               Closed      Work Done
# ...      ...        ...              ...                  ...            ...
# 22857  CLOSE 2019-09-04           CLOSED               Closed      Work Done
# 22869  CLOSE 2020-01-30           CLOSED               Closed      Work Done
# 22986  CLOSE 2020-03-31           CLOSED               Closed      Work Done
# 22999  CLOSE 2020-06-29           CLOSED               Closed      Work Done
# 23070  CLOSE 2019-01-09           CLOSED               Closed      Work Done
#
#       ZZSUBWORKTYPE             CAUSE  REMEDY ZZRESCODE  \
# 502        BUILDING        NORMALWEAR  REMEDY       NaN
# 834             NaN               NaN     NaN       NaN
# 1128            NaN        NORMALWEAR  REMEDY       NaN
# 1156            NaN  ACCIDENTALDAMAGE  REMEDY       NaN
# 1311            NaN        NORMALWEAR  REMEDY       NaN
# ...             ...               ...     ...       ...
# 22857           NaN        NORMALWEAR  REMEDY       NaN
# 22869           NaN        NORMALWEAR  REMEDY       NaN
# 22986           NaN        NORMALWEAR  REMEDY       NaN
# 22999           NaN  ACCIDENTALDAMAGE  REMEDY       NaN
# 23070           NaN        NORMALWEAR  REMEDY       NaN
#
#       LAST_LABTRANS_TRANSTYPE  TOTAL_REPAIRS_DONE  \
# 502                      WORK                 1.0
# 834                INSPECTION                 NaN
# 1128                     WORK                 1.0
# 1156                     WORK                 2.0
# 1311                     WORK                 1.0
# ...                       ...                 ...
# 22857                    WORK                 1.0
# 22869                    WORK                 1.0
# 22986                    WORK                 2.0
# 22999                    WORK                 1.0
# 23070                    WORK                 1.0
#
#                    REPAIRS_DONE_LIST  VANDALISM_CODE  ZZCOURTORDER  \
# 502                   CEMENTREPAIRED             0.0           0.0
# 834                              NaN             0.0           0.0
# 1128               COMPACTORREPAIRED             0.0           0.0
# 1156      WALLREPAIRED;SHORTREPAIRED             0.0           0.0
# 1311               COMPACTORREPAIRED             0.0           0.0
# ...                              ...             ...           ...
# 22857              COMPACTORREPAIRED             0.0           0.0
# 22869              COMPACTORREPAIRED             0.0           0.0
# 22986  HOSEREPLCED;COMPACTORREPAIRED             0.0           0.0
# 22999                  POWERRESTORED             0.0           0.0
# 23070              COMPACTORREPAIRED             0.0           0.0
#
#       ZZRRPWORKREQUIRED ZZRRPWORKAMOUNT  \
# 502                 NaN             NaN
# 834                 NaN             NaN
# 1128                NaN             NaN
# 1156                NaN             NaN
# 1311                NaN             NaN
# ...                 ...             ...
# 22857               NaN             NaN
# 22869               NaN             NaN
# 22986               NaN             NaN
# 22999               NaN             NaN
# 23070               NaN             NaN
#
#                                              DESCRIPTION  \
# 502                            EXTERIORCOMPACTOR - MAINT
# 834                            EXTERIORCOMPACTOR - MAINT
# 1128                          EXTERIOR COMPACTOR - MAINT
# 1156                       EXTERIOR COMPACTOR - ELECTRCN
# 1311             EZ PAC #2 HOSE IS LEAKING HYDRAULIC OIL
# ...                                                  ...
# 22857                 exterior compactor OOO busted hose
# 22869                          EXTERIORCOMPACTOR - MAINT
# 22986  EXTERIOR COMPACTOR #1-HOSE POPPED,LEAKING-BUCK...
# 22999                      EXTERIOR COMPACTOR - ELECTRCN
# 23070                         EXTERIOR COMPACTOR - MAINT
#
#        Days to Complete Or Still Open  TDS  BUILDING STAIRHALL ROOM  \
# 502                          0.250000  215       1.0       NaN  NaN
# 834                          6.724468   30       NaN       NaN  NaN
# 1128                         1.775486  262       1.0       NaN  NaN
# 1156                         0.291667   55       4.0       NaN  NaN
# 1311                         2.173623    9      11.0       NaN  NaN
# ...                               ...  ...       ...       ...  ...
# 22857                        8.787095   93       1.0       NaN  NaN
# 22869                        5.154583  121       7.0       NaN  NaN
# 22986                        0.957222   34       6.0       NaN  NaN
# 22999                        0.292917  118       5.0       NaN  NaN
# 23070                        5.873947   86       NaN       NaN  NaN
#
#                             PROBLEMANDFAILURE      CATEGORY
# 502               RETWALLDMLEXTERIORCOMPACTOR  EXTCOMPACTOR
# 834               RAMDAMAGEDEXTERIORCOMPACTOR  EXTCOMPACTOR
# 1128             HOSEOILLEAKEXTERIORCOMPACTOR  EXTCOMPACTOR
# 1156            EXPOSEDWIRESEXTERIORCOMPACTOR  EXTCOMPACTOR
# 1311             HOSEOILLEAKEXTERIORCOMPACTOR  EXTCOMPACTOR
# ...                                       ...           ...
# 22857        EXTCOMPACTOROOOEXTERIORCOMPACTOR  EXTCOMPACTOR
# 22869  LOADERBUCKETNOTMOVINGEXTERIORCOMPACTOR  EXTCOMPACTOR
# 22986  LOADERBUCKETNOTMOVINGEXTERIORCOMPACTOR  EXTCOMPACTOR
# 22999                NOPOWEREXTERIORCOMPACTOR  EXTCOMPACTOR
# 23070         FITTINGOILLEAKEXTERIORCOMPACTOR  EXTCOMPACTOR
#
# [258 rows x 51 columns]

# %%
#comp['ZZCREATEWEEK'] = comp['ZZCREATEDATE'].dt.week

# %%
#1. Groupby Category, Building, and Room
tds_rm_grp = comp.groupby(['CONSOLIDATED_TDS_NUM', 'CONSOLIDATED_NAME','TDS_NUM','DEVELOPMENT_NAME','CATEGORY','BUILDING', 'ROOM']).size().reset_index(name='Freq')
#2. Groupby Category, Buidling, Room, Month, Year
tds_rmstrt_grp =

# %%
tds_rm_grp[tds_rm_grp["Freq"]>5]
# Out:
#        CONSOLIDATED_TDS_NUM   CONSOLIDATED_NAME  TDS_NUM    DEVELOPMENT_NAME  \
# 19                        3        Harlem River        3        HARLEM RIVER
# 38                        3        Harlem River        3        HARLEM RIVER
# 39                        3        Harlem River        3        HARLEM RIVER
# 40                        3        Harlem River        3        HARLEM RIVER
# 41                        3        Harlem River        3        HARLEM RIVER
# ...                     ...                 ...      ...                 ...
# 10986                   505  Queensbridge North      505  QUEENSBRIDGE NORTH
# 10991                   505  Queensbridge North      505  QUEENSBRIDGE NORTH
# 11028                   514             Whitman      514             WHITMAN
# 11030                   514             Whitman      514             WHITMAN
# 11047                   514             Whitman      514             WHITMAN
#
#            CATEGORY BUILDING   ROOM  Freq
# 19     INTCOMPACTOR       02    F01     8
# 38            PAINT       01    F01     8
# 39            PAINT       02    F01     7
# 40            PAINT       03    F01     6
# 41            PAINT       04    F01     8
# ...             ...      ...    ...   ...
# 10986         PESTS       21  COM01     6
# 10991         PESTS       22  COM01     6
# 11028          ELEC       38    F01     7
# 11030  EXTCOMPACTOR       10  GND01    14
# 11047  INTCOMPACTOR       01  COM01     6
#
# [471 rows x 8 columns]

# %%
tds_rm_cnt = tds_rm_grp[tds_rm_grp["Freq"]>5].pivot_table(index=['CONSOLIDATED_TDS_NUM', 'CONSOLIDATED_NAME','TDS_NUM','DEVELOPMENT_NAME', 'BUILDING', 'ROOM'], columns='CATEGORY', values='Freq').reset_index().rename_axis(None, axis=1)

# %%
tds_rm_cnt
# Out:
#      CONSOLIDATED_TDS_NUM   CONSOLIDATED_NAME  TDS_NUM    DEVELOPMENT_NAME  \
# 0                       3        Harlem River        3        HARLEM RIVER
# 1                       3        Harlem River        3        HARLEM RIVER
# 2                       3        Harlem River        3        HARLEM RIVER
# 3                       3        Harlem River        3        HARLEM RIVER
# 4                       3        Harlem River        3        HARLEM RIVER
# ..                    ...                 ...      ...                 ...
# 436                   505  Queensbridge North      505  QUEENSBRIDGE NORTH
# 437                   505  Queensbridge North      505  QUEENSBRIDGE NORTH
# 438                   514             Whitman      514             WHITMAN
# 439                   514             Whitman      514             WHITMAN
# 440                   514             Whitman      514             WHITMAN
#
#     BUILDING   ROOM  BULK  DOOR  ELEC  EXTCOMPACTOR  INTCOMPACTOR  LIGHT  \
# 0          1    F01   NaN   NaN   NaN           NaN           NaN    NaN
# 1          4    F01   NaN   NaN   NaN           NaN           NaN    NaN
# 2          5    F01   NaN   NaN   NaN           NaN           NaN    NaN
# 3         01    F01   NaN   NaN   NaN           NaN           NaN    NaN
# 4         02    F01   NaN   NaN   NaN           NaN           8.0    NaN
# ..       ...    ...   ...   ...   ...           ...           ...    ...
# 436       21  COM01   NaN   NaN   NaN           NaN           NaN    NaN
# 437       22  COM01   NaN   NaN   NaN           NaN           NaN    NaN
# 438       01  COM01   NaN   NaN   NaN           NaN           6.0    NaN
# 439       10  GND01   NaN   NaN   NaN          14.0           NaN    NaN
# 440       38    F01   NaN   NaN   7.0           NaN           NaN    NaN
#
#      OTHER  PAINT  PESTS  PLUMBING
# 0      NaN    NaN    6.0       NaN
# 1      NaN    NaN    6.0       NaN
# 2      NaN    NaN    7.0       NaN
# 3      NaN    8.0    NaN       NaN
# 4      NaN    7.0    NaN       NaN
# ..     ...    ...    ...       ...
# 436    NaN    NaN    6.0       NaN
# 437    NaN    NaN    6.0       NaN
# 438    NaN    NaN    NaN       NaN
# 439    NaN    NaN    NaN       NaN
# 440    NaN    NaN    NaN       NaN
#
# [441 rows x 16 columns]

# %%
comp[comp['BUILDING'] == ]
# Out:
# Empty DataFrame
# Columns: [GEOGRAPHICAL_BOROUGH_NAME, NEW_BOROUGH_GROUPING, RAM, CONSOLIDATED_NAME, CONSOLIDATED_TDS_NUM, DEVELOPMENT_NAME, TDS_NUM, ADDRESS_LINE_1, BUILDING_NUM, LOCATION, LOCATION_TYPE, OWNERGROUP, SOURCESYSID, CALL_CENTER_TYPE, PARENT, WONUM, TRADE_TYPE, CRAFT_DESCRIPTION, FAILURECODE, PROBLEMCODE, WOPRIORITY, REPORTDATE, ZZCREATEDATE, SCHEDSTART, TARGSTARTDATE, ACTSTART, ACTFINISH, STATUS, STATUSDATE, DISPOSITION_DESC, DISPOSITION_SUB_DESC, WORK_DONE_DESC, ZZSUBWORKTYPE, CAUSE, REMEDY, ZZRESCODE, LAST_LABTRANS_TRANSTYPE, TOTAL_REPAIRS_DONE, REPAIRS_DONE_LIST, VANDALISM_CODE, ZZCOURTORDER, ZZRRPWORKREQUIRED, ZZRRPWORKAMOUNT, DESCRIPTION, Days to Complete Or Still Open, TDS, BUILDING, STAIRHALL, ROOM, PROBLEMANDFAILURE, CATEGORY]
# Index: []

# %%
comp
# Out:
#       GEOGRAPHICAL_BOROUGH_NAME  NEW_BOROUGH_GROUPING        RAM  \
# 0                      Brooklyn              Brooklyn    MAYNARD
# 1                     Manhattan             Manhattan      SUGGS
# 2                     Manhattan             Manhattan      SUGGS
# 3                        Queens  Queens-Staten Island   CORIOLAN
# 4                        Queens  Queens-Staten Island   CORIOLAN
# ...                         ...                   ...        ...
# 23087                     Bronx                 Bronx   TOLOZANO
# 23088                 Manhattan             Manhattan      SUGGS
# 23089                  Brooklyn              Brooklyn  MIDDLETON
# 23090                     Bronx                 Bronx   THEODORE
# 23091                  Brooklyn              Brooklyn    MAYNARD
#
#             CONSOLIDATED_NAME  CONSOLIDATED_TDS_NUM  \
# 0                Williamsburg                     2
# 1                Harlem River                     3
# 2                Harlem River                     3
# 3          Queensbridge South                     5
# 4          Queensbridge South                     5
# ...                       ...                   ...
# 23087                Parkside                    47
# 23088            Harlem River                     3
# 23089         Reid Apartments                   167
# 23090  Claremont Consolidated                   308
# 23091            Williamsburg                     2
#
#                 DEVELOPMENT_NAME  TDS_NUM          ADDRESS_LINE_1  \
# 0                   WILLIAMSBURG        2       219 TEN EYCK WALK
# 1                   HARLEM RIVER        3   231 WEST 151ST STREET
# 2                   HARLEM RIVER        3  210Q WEST 153RD STREET
# 3             QUEENSBRIDGE SOUTH        5  41-10 VERNON BOULEVARD
# 4             QUEENSBRIDGE SOUTH        5  41-10 VERNON BOULEVARD
# ...                          ...      ...                     ...
# 23087                   PARKSIDE       47        665 ARNOW AVENUE
# 23088                    AUDUBON      125   1909 AMSTERDAM AVENUE
# 23089      TAPSCOTT STREET REHAB      354     184 TAPSCOTT STREET
# 23090  CLAREMONT REHAB (GROUP 4)      335        1228 CLAY AVENUE
# 23091               WILLIAMSBURG        2       142 MAUJER STREET
#
#       BUILDING_NUM          LOCATION   LOCATION_TYPE OWNERGROUP SOURCESYSID  \
# 0               16      002.16.GND01         GROUNDS     DEV002      SIEBEL
# 1               GN         003.GND01         GROUNDS   TSDWASTE      MAXIMO
# 2                1      003.01.GND01         GROUNDS     DEV003      SIEBEL
# 3               25      005.25.GND01         GROUNDS     DEV005      MAXIMO
# 4               25      005.25.GND01         GROUNDS     DEV005      MAXIMO
# ...            ...               ...             ...        ...         ...
# 23087           06  047.06.B01.COM02  COMPACTOR ROOM    BXPAINT      MAXIMO
# 23088           01  125.01.B01.COM01  COMPACTOR ROOM      MNEXT      MAXIMO
# 23089           05  354.05.B01.COM01  COMPACTOR ROOM     DEV167      MAXIMO
# 23090           04  335.04.B01.COM01  COMPACTOR ROOM      BXEXT      MOBILE
# 23091           08  002.08.B01.COM01  COMPACTOR ROOM     DEV002      SIEBEL
#
#       CALL_CENTER_TYPE      PARENT       WONUM      TRADE_TYPE  \
# 0                  CCC  67708837.0  67708837.0     MAINTENANCE
# 1              Non-CCC  72867943.0  72867943.0     MAINTENANCE
# 2                  CCC  66031837.0  66031837.0     MAINTENANCE
# 3              Non-CCC  65740409.0  65740409.0  SKILLED TRADES
# 4              Non-CCC  65772949.0  65772949.0  SKILLED TRADES
# ...                ...         ...         ...             ...
# 23087          Non-CCC  74268918.0  74268918.0  SKILLED TRADES
# 23088          Non-CCC  74265116.0  74265116.0  SKILLED TRADES
# 23089          Non-CCC  74273994.0  74273994.0  SKILLED TRADES
# 23090          Non-CCC  74272982.0  74272982.0  SKILLED TRADES
# 23091              CCC  73624949.0  73624949.0  SKILLED TRADES
#
#         CRAFT_DESCRIPTION    FAILURECODE    PROBLEMCODE  WOPRIORITY  \
# 0             Maintenance      COMPACTOR          NOISY         3.0
# 1             Maintenance      COMPACTOR   COMPACTOROOO         3.0
# 2             Maintenance      COMPACTOR          NOISY         3.0
# 3                  Vendor      COMPACTOR  NEEDSCLEANING         3.0
# 4                  Vendor      COMPACTOR   COMPACTOROOO         3.0
# ...                   ...            ...            ...         ...
# 23087             Painter          PAINT  NEEDSPAINTING         3.0
# 23088        Exterminator  EXTERMINATION           RATS         7.0
# 23089              Vendor         DRAINS       STOPPAGE         7.0
# 23090        Exterminator  EXTERMINATION           RATS         7.0
# 23091  Supv of Caretakers    DEBRISSPILL         DEBRIS         3.0
#
#       REPORTDATE ZZCREATEDATE SCHEDSTART TARGSTARTDATE   ACTSTART  ACTFINISH  \
# 0     2019-07-11   2019-07-11 2019-09-16    2019-09-16 2019-07-18 2019-07-18
# 1     2020-03-07   2020-03-07        NaT           NaT 2020-03-09 2020-03-09
# 2     2019-03-27   2019-03-27        NaT           NaT 2019-04-02 2019-04-02
# 3     2019-02-28   2019-02-28        NaT           NaT 2019-03-13 2019-03-13
# 4     2019-03-04   2019-03-04        NaT           NaT 2019-05-29 2019-05-29
# ...          ...          ...        ...           ...        ...        ...
# 23087 2020-06-29   2020-06-29        NaT           NaT 2020-06-29 2020-06-29
# 23088 2020-06-29   2020-06-29 2020-07-14    2020-07-14 2020-06-29 2020-06-29
# 23089 2020-06-29   2020-06-29        NaT           NaT        NaT        NaT
# 23090 2020-06-29   2020-06-29        NaT           NaT 2020-06-29 2020-06-29
# 23091 2020-05-06   2020-05-06        NaT           NaT 2020-05-08 2020-05-08
#
#       STATUS STATUSDATE DISPOSITION_DESC   DISPOSITION_SUB_DESC  \
# 0      CLOSE 2019-07-18           CLOSED  Condition not Founded
# 1      CLOSE 2020-03-09           CLOSED                 Closed
# 2      CLOSE 2019-04-02           CLOSED  Condition not Founded
# 3      CLOSE 2019-03-13           CLOSED  Condition not Founded
# 4      CLOSE 2019-05-30           CLOSED                 Closed
# ...      ...        ...              ...                    ...
# 23087  CLOSE 2020-06-30           CLOSED                 Closed
# 23088  CLOSE 2020-06-29           CLOSED                 Closed
# 23089   APPR 2020-06-29             OPEN               Approved
# 23090  CLOSE 2020-06-29           CLOSED                 Closed
# 23091  CLOSE 2020-05-08           CLOSED                 Closed
#
#       WORK_DONE_DESC ZZSUBWORKTYPE             CAUSE  REMEDY ZZRESCODE  \
# 0      Work Not Done           NaN        NORMALWEAR  REMEDY       NaN
# 1          Work Done           NaN        NORMALWEAR  REMEDY       NaN
# 2      Work Not Done      BUILDING  ACCIDENTALDAMAGE  REMEDY       NaN
# 3      Work Not Done           NaN        NORMALWEAR  REMEDY       NaN
# 4          Work Done           NaN        NORMALWEAR  REMEDY       NaN
# ...              ...           ...               ...     ...       ...
# 23087      Work Done           NaN        NORMALWEAR  REMEDY       NaN
# 23088      Work Done           NaN        NORMALWEAR  REMEDY       NaN
# 23089           Open           NaN               NaN     NaN       NaN
# 23090      Work Done           NaN        NORMALWEAR  REMEDY       NaN
# 23091      Work Done           NaN        NORMALWEAR  REMEDY       NaN
#
#       LAST_LABTRANS_TRANSTYPE  TOTAL_REPAIRS_DONE  \
# 0                   UNFOUNDED                 5.0
# 1                        WORK                 1.0
# 2                   UNFOUNDED                 3.0
# 3                   UNFOUNDED                 1.0
# 4                        WORK                 2.0
# ...                       ...                 ...
# 23087                    WORK                 1.0
# 23088                    WORK                 1.0
# 23089                     NaN                 NaN
# 23090                    WORK                 2.0
# 23091                    WORK                 2.0
#
#                                        REPAIRS_DONE_LIST  VANDALISM_CODE  \
# 0      BALASTREPAIRED;WIRESECURED;FIXTUREREPAIRED;BUL...             0.0
# 1                                  HYDROLICFLUIDREPLACED             0.0
# 2      KEYSWITCHREPAIRED;SHORTREPAIRED;KEYSWITCHREPLACED             0.0
# 3                                 EMERSTOPSWITCHREPLACED             0.0
# 4                COPINGSTONEREPAIRED;COPINGSTONEREPLACED             0.0
# ...                                                  ...             ...
# 23087                                            PAINTED             0.0
# 23088                                        AREATREATED             0.0
# 23089                                                NaN             0.0
# 23090                  TREATED_AND_INSPECTED;AREATREATED             0.0
# 23091                       GARBAGECLEANED;DEBRISREMOVED             0.0
#
#        ZZCOURTORDER ZZRRPWORKREQUIRED ZZRRPWORKAMOUNT  \
# 0               0.0               NaN             NaN
# 1               0.0                 N             NaN
# 2               0.0               NaN             NaN
# 3               0.0                 N             NaN
# 4               0.0                 N             NaN
# ...             ...               ...             ...
# 23087           0.0                 N             NaN
# 23088           0.0               NaN             NaN
# 23089           0.0               NaN             NaN
# 23090           0.0               NaN             NaN
# 23091           0.0               NaN             NaN
#
#                                    DESCRIPTION  \
# 0                            COMPACTOR - MAINT
# 1                           exterior compactor
# 2                            COMPACTOR - MAINT
# 3                     Generic Vendor Work Plan
# 4      EZ PAK #1 AND #2 NEED IMMEDIATE REPAIRS
# ...                                        ...
# 23087                          PAINT - PAINTER
# 23088                            EXTERMINATION
# 23089                 Generic Vendor Work Plan
# 23090                        PAIS EXTERMINATOR
# 23091                       DEBRISSPILL - SOHC
#
#        Days to Complete Or Still Open  TDS  BUILDING STAIRHALL  \
# 0                            6.779699    2      16.0       B01
# 1                            1.889479    3       6.0       B01
# 2                            6.263889    3       1.0       NaN
# 3                           12.955637    5      25.0       B01
# 4                           85.809560    5      25.0       B01
# ...                               ...  ...       ...       ...
# 23087                        0.404618   47       6.0       B01
# 23088                        0.089352  125       1.0       B01
# 23089                        6.436933  354       5.0       B01
# 23090                        0.067130  335       4.0       B01
# 23091                        1.627014    2       8.0       B01
#
#                                         ROOM       PROBLEMANDFAILURE  \
# 0      Unknown - Originally entered as GND01          NOISYCOMPACTOR
# 1                                      GND01   COMPACTOROOOCOMPACTOR
# 2                                      GND01          NOISYCOMPACTOR
# 3                                      GND01  NEEDSCLEANINGCOMPACTOR
# 4                                      GND01   COMPACTOROOOCOMPACTOR
# ...                                      ...                     ...
# 23087                                  COM02      NEEDSPAINTINGPAINT
# 23088                                  COM01       RATSEXTERMINATION
# 23089                                  COM01          STOPPAGEDRAINS
# 23090                                  COM01       RATSEXTERMINATION
# 23091                                  COM01       DEBRISDEBRISSPILL
#
#            CATEGORY
# 0      INTCOMPACTOR
# 1      EXTCOMPACTOR
# 2      EXTCOMPACTOR
# 3      EXTCOMPACTOR
# 4      EXTCOMPACTOR
# ...             ...
# 23087         PAINT
# 23088         PESTS
# 23089      PLUMBING
# 23090         PESTS
# 23091         OTHER
#
# [23092 rows x 51 columns]
